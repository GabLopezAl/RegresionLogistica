# %%
# Importacion de librerías a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as mt
import seaborn as sns
import scipy.special as special
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Leer dataset a tratar
df = pd.read_csv("Datos_limpios_Berlin.csv")
df = df.drop("Unnamed: 0", axis=1)
df.head()
# Out:
#   last_scraped                                               name  \
# 0   18/09/2024                  130 sqm with a view on Mauer Park
# 1   18/09/2024                  light quiet beautiful 4 room flat
# 2   18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3   18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4   18/09/2024  Room w/ balcony and private bathroom in nice area
#
#                                          description  \
# 0  An apartment of 130 sqm right in the heart of ...
# 1  We offer our 4 room apartment in Prenzlauer Be...
# 2  Our fantastic typical Berlin-style apartment i...
# 3  I am renting out my spacious, bright rooftop a...
# 4  I¬¨¬•m offering a guest room with balcony in m...
#
#                                neighborhood_overview  \
# 0  Prenzlauer Berg is no doubt one of the most my...
# 1  Prenzlauer Berg is no doubt one of the most my...
# 2  Prenzlauer Berg is no doubt one of the most my...
# ...

# %% [markdown]
# **Primera variable: host_response_time**

# %%
df["host_response_time"].unique()
# Out:
# array(['within an hour', 'within a few hours', 'within a day',
#        'a few days or more'], dtype=object)

# %%
# Se usará la variable objetivo host_response_time a predecir con ayuda de las siguientes variables independientes:
# host_acceptance_rate
# host_is_superhost
# number_of_reviews

# Sustituimos los valores de t y f por números: 1 y 0
df["host_is_superhost"] = df["host_is_superhost"].replace({"f":0,"t":1})
df["host_is_superhost"]

# Convertimos nuestra variable objetivo a números
encoder = LabelEncoder()
df["host_response_time"] = encoder.fit_transform(df["host_response_time"])
df["host_response_time"].unique()

# Convertimos
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2540\646437218.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["host_is_superhost"] = df["host_is_superhost"].replace({"f":0,"t":1})
# array([3, 2, 1, 0])

# %%
# Declaramos las variables dependientes e independientes para el análisis de regresión
vars_indep = df[["host_acceptance_rate","host_is_superhost","number_of_reviews"]]
var_dep = df["host_response_time"]

# %%
# Redefinimos las variables 
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# %%
# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 3, 1, 1], shape=(3459,))

# %%
# visualizaremos la matriz de confusion para ver el endiemiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[   0   93    0   10]
#  [   0 1525   15  150]
#  [   0  196   20  169]
#  [   0  560   12  709]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.         0.64237574 0.42553191 0.68304432]
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.43773799200959884
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.6516334200636021

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.37694719110229824

# %% [markdown]
# **Segunda variable: host_is_superhost**

# %%
# Declaramos las variables dependientes e independentes
vars_indep = df[["host_response_rate", "host_acceptance_rate", "host_total_listings_count"]]
var_dep = df["host_is_superhost"]

# %%
# Redefinimos las variables
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# %%
# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(3459,))

# %%
# visualizaremos la matriz de confusion para ver el rendimiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[2673    5]
#  [ 781    0]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.77388535 0.        ]

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.3869426751592357

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.7727666955767563

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.49906646751306943

# %% [markdown]
# **Tercera variable: beds**

# %%
# Convertimos la variable beds a numérica
encoder = LabelEncoder()
df["beds"] = encoder.fit_transform(df["beds"])
df["beds"].unique()
# Out:
# array([4, 1, 3, 2, 0])

# %%
# convertimos la variable room_type a numérica
encoder = LabelEncoder()
df["room_type"] = encoder.fit_transform(df["room_type"])
df["room_type"].unique()
# Out:
# array([0, 2, 3, 1])

# %%
# Declaramos las variables para la regresión
vars_indep = df[["accommodates", "bedrooms", "room_type"]]
var_dep = df["beds"]

# %%
# Redefinimos las variables
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([3, 3, 3, ..., 3, 3, 3], shape=(8069,))

# %%
# visualizaremos la matriz de confusion para ver el rendimiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[   0   15    2   47    0]
#  [   0  406    9 1907    0]
#  [   0    1  203  395    0]
#  [   0  455  144 3957    0]
#  [   0    4  131  393    0]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.         0.46083995 0.41513292 0.59068518 0.        ]
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.29333161116490014
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.5658693766265956

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.27645449068552236

# %% [markdown]
# **Cuarta variable: host_has_profile_pic**

# %%
# Convetir variable objetivo a números
df["host_has_profile_pic"] = df["host_has_profile_pic"].replace({"t":1, "f":0})
df["host_has_profile_pic"].unique()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2540\2459435029.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["host_has_profile_pic"] = df["host_has_profile_pic"].replace({"t":1, "f":0})
# array([1, 0])

# %%
# Convertir varible host_verifications a números
encoder = LabelEncoder()
df["host_verifications"] = encoder.fit_transform(df["host_verifications"])
df["host_verifications"].unique()
# Out:
# array([1, 0, 5, 3, 2, 4, 6])

# %%
# Declarar las variables indep y objetivo
vars_indep = df[["host_listings_count", "host_verifications", "host_is_superhost"]]
var_dep = df["host_has_profile_pic"]

# %%
# Redefinimos las variables
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(8069,))

# %%
# visualizaremos la matriz de confusion para ver el rendimiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[   0  105]
#  [   0 7964]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.         0.98698724]
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.49349361754864296
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.9869872350972859

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.5

# %% [markdown]
# **Quinta variable: host_identity_verified**

# %%
# Convertimos nuestra variable objetivo a números
df["host_identity_verified"] = df["host_identity_verified"].replace({"t":1, "f":0})
df["host_identity_verified"].unique()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2540\1942142975.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["host_identity_verified"] = df["host_identity_verified"].replace({"t":1, "f":0})
# array([1, 0])

# %%
# Definimos nuestras variables dep e indep
vars_indep = df[["host_is_superhost","review_scores_communication","review_scores_rating"]]
var_dep = df["host_identity_verified"]

# %%
# Definimos nuestras variables
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(8069,))

# %%
# visualizaremos la matriz de confusion para ver el rendimiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[   0  746]
#  [   0 7323]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.        0.9075474]
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.4537737018217871
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.9075474036435742

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.5

# %% [markdown]
# **Sexta variable: room_type**

# %%
# Convertir variable independiente a números
df["property_type"] = encoder.fit_transform(df["property_type"])
df["property_type"].unique()
# Out:
# array([15, 38,  8, 13, 10, 12, 36, 30, 33, 22, 17, 34, 54, 14, 11, 20, 23,
#        57,  5,  0, 45,  9, 42, 19, 16, 46, 59, 52, 44, 41, 31, 48, 47, 32,
#        49, 28,  7, 18, 25,  1, 37, 39, 53, 56, 21,  6, 24, 26, 35, 43,  3,
#        50, 58, 27, 40, 51, 55,  4,  2, 29])

# %%
# Definimos nuestras variables indep y dep
vars_indep = df[["property_type","accommodates","price"]]
var_dep = df["room_type"]

# %%
# Asignamos las variables
X = vars_indep
y = var_dep

# %%
# Dividimos los datos en conjunto de prueba y entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.3, random_state=None)

# %%
# Definimos la funcion de escalar
escalar = StandardScaler()

# Escalamos nuestros datos
x_train = escalar.fit_transform(X_train)
x_test = escalar.transform(X_test)

# %%
# Definimos la funcion del modelo a utilizar
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()

# %%
# Entrenamos el modelo con los datos de entrenamiento
modelo.fit(X_train, y_train)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Realizamos las predicciones del modelo
y_pred = modelo.predict(X_test)
y_pred
# Out:
# array([2, 0, 2, ..., 2, 0, 0], shape=(8069,))

# %%
# visualizaremos la matriz de confusion para ver el rendimiento del modelo
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test,y_pred)
print("Matriz de confusion")
print(matriz)
# Out:
# Matriz de confusion
# [[5260    0   30    0]
#  [   0    0   72    0]
#  [  80    0 2538    1]
#  [   0    0   84    4]]

# %%
# Calculamos la precisión del modelo para cada clase
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average=None)
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# [0.98501873 0.         0.93171806 0.8       ]
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la precision del modelo en general
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="macro")
print("Precisión del modelo")
print(precision)
# Out:
# Precisión del modelo
# 0.6791841970664423
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calculamos la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print("Exactitud del modelo")
print(exactitud)
# Out:
# Exactitud del modelo
# 0.9669103978188127

# %%
# Calculamos la sensibilidad del modelo (verdaderos positivos)
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="macro")
print("Sensibilidad del modelo")
print(sensibilidad)
# Out:
# Sensibilidad del modelo
# 0.5022139082245682
